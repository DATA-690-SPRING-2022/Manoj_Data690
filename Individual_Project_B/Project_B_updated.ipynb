# %% [markdown]
# <a href="https://colab.research.google.com/github/manojboyapati/Manoj_Data690/blob/main/Individual_Project_B/Project_B_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part B Draft
#
# Date:02/04/2022
#
# DS25779
#
# Manoj Kumar Boyapati

# %% [markdown]
# # Access to Electricity
#
# Around 13% of the world does not have access to electricity. For poverty reduction, economic growth, and standard of living improvements, electricity is essential. Measuring the percentage of people who have access to electricity is thus an important social and economic indicator. There is no universally accepted definition of what it means to have access to electricity. The majority of definitions, on the other hand, are focused on the provision of electricity, safe cooking facilities, and a required minimum level of consumption.
# The International Energy Agency's (IEA) definition encompasses more than just household delivery. It also requires households to meet a minimum level of electricity, which varies depending on whether the household is rural or urban and rises over time. This minimum threshold is 250 kilowatt-hours (kWh) per year for rural households and 500 kWh per year for urban households.

# %% [markdown]
# Data Source - World Development Explorer
#
# Topic :
# Energy And Mining
#
# Indicators :
#
# Access to electricity rural
#
# Access to electricity urban
#
# Access to electricity total
#
# Electricity production from coal, gas and oil sources
#
# Electricity production from Hydroelectric sources
#
# Renewable electricity output
#
# Analyzing Countries - United States of America, India, China
#
# Time Plot: 2010 - 2018

# %%
import pandas as pd
import plotly
import plotly.express as px

#DATA = "https://raw.githubusercontent.com/manojboyapati/Manoj_Data690/main/Individual_Project_B/wdi_data_access1.csv"
#DATA = "https://raw.githubusercontent.com/manojboyapati/Manoj_Data690/main/Individual_Project_B/wdi_data_urban.csv"
#DATA = "https://raw.githubusercontent.com/manojboyapati/Manoj_Data690/main/Individual_Project_B/wdi_data_coal.csv"
#DATA = "https://raw.githubusercontent.com/manojboyapati/Manoj_Data690/main/Individual_Project_B/wdi_hydro.csv"
#DATA = "https://raw.githubusercontent.com/manojboyapati/Manoj_Data690/main/Individual_Project_B/wdi_All.csv"
#DATA = "https://raw.githubusercontent.com/manojboyapati/Manoj_Data690/main/Individual_Project_B/wdi_consumption.csv"
DATA = "https://github.com/manojboyapati/Manoj_Data690/blob/main/Individual_Project_B/wdi_kg.csv"
DATA = "https://raw.githubusercontent.com/manojboyapati/Manoj_Data690/main/Individual_Project_B/wdi_loss.csv"

# %%
df = pd.read_csv(DATA)

df.sample(10)
# Out:
#      Unnamed: 0  Year         value          indicator Country Code  \
# 175         175  2012  1.265780e+09        SP.POP.TOTL          IND
# 167         167  2015  1.379860e+09        SP.POP.TOTL          CHN
# 115         115  2011  9.985722e+01     EG.ELC.ACCS.ZS          CHN
# 157         157  2011  4.334576e+01     EG.ELC.COAL.ZS          USA
# 104         104  2010  1.000000e+02  EG.ELC.ACCS.UR.ZS          USA
# 77           77  2013  1.000000e+02  EG.ELC.ACCS.RU.ZS          USA
# 14           14  2012  6.886284e+01     EG.ELC.FOSL.ZS          USA
# 112         112  2018  1.000000e+02  EG.ELC.ACCS.UR.ZS          USA
# 76           76  2012  1.000000e+02  EG.ELC.ACCS.RU.ZS          USA
# 55           55  2011  9.971150e+01  EG.ELC.ACCS.RU.ZS          CHN
#
#       Country Name               Region         Income Group    Lending Type
# 175          India           South Asia  Lower middle income            IBRD
# ...

# %%
df['Country Name'].unique()
# Out:
# array(['China', 'India', 'United States'], dtype=object)

# %%
df_Pop = df.query("indicator == 'EG.ELC.ACCS.ZS' ")
df_Pop
# Out:
#      Unnamed: 0  Year       value       indicator Country Code   Country Name  \
# 114         114  2010   99.700000  EG.ELC.ACCS.ZS          CHN          China
# 115         115  2011   99.857224  EG.ELC.ACCS.ZS          CHN          China
# 116         116  2012   99.964874  EG.ELC.ACCS.ZS          CHN          China
# 117         117  2013   99.997009  EG.ELC.ACCS.ZS          CHN          China
# 118         118  2014  100.000000  EG.ELC.ACCS.ZS          CHN          China
# 119         119  2015  100.000000  EG.ELC.ACCS.ZS          CHN          China
# 120         120  2016  100.000000  EG.ELC.ACCS.ZS          CHN          China
# 121         121  2017  100.000000  EG.ELC.ACCS.ZS          CHN          China
# 122         122  2018  100.000000  EG.ELC.ACCS.ZS          CHN          China
# 123         123  2019  100.000000  EG.ELC.ACCS.ZS          CHN          China
# 124         124  2010   76.300000  EG.ELC.ACCS.ZS          IND          India
# ...

# %%
df_Pop = df.query("Year == 2015").query("indicator == 'EG.ELC.ACCS.ZS'")

df_Pop_sort = df_Pop.sort_values(by= "value", ascending= False)
df_Pop_sort
# Out:
#      Unnamed: 0  Year  value       indicator Country Code   Country Name  \
# 119         119  2015  100.0  EG.ELC.ACCS.ZS          CHN          China
# 139         139  2015  100.0  EG.ELC.ACCS.ZS          USA  United States
# 129         129  2015   88.0  EG.ELC.ACCS.ZS          IND          India
#
#                   Region         Income Group    Lending Type
# 119  East Asia & Pacific  Upper middle income            IBRD
# 139        North America          High income  Not classified
# 129           South Asia  Lower middle income            IBRD

# %%
fig = px.bar(
    df_Pop_sort, 
    x="Country Name", 
    labels={"value":"2010 Electric power transmission and distribution"},
    y="value",
    color="Country Name",
    height=700,
    template=list(plotly.io.templates.keys())[5],
    title="Top 3 countries by 2015 Access to electricity(% of population)"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_Accs = df.query("Year == 2015").query("indicator == 'EG.ELC.ACCS.RU.ZS'")

df_Accs_sort = df_Accs.sort_values(by= "value", ascending= False)
df_Accs_sort
# Out:
#     Unnamed: 0  Year       value          indicator Country Code  \
# 59          59  2015  100.000000  EG.ELC.ACCS.RU.ZS          CHN
# 79          79  2015  100.000000  EG.ELC.ACCS.RU.ZS          USA
# 69          69  2015   83.367932  EG.ELC.ACCS.RU.ZS          IND
#
#      Country Name               Region         Income Group    Lending Type
# 59          China  East Asia & Pacific  Upper middle income            IBRD
# 79  United States        North America          High income  Not classified
# 69          India           South Asia  Lower middle income            IBRD

# %%
fig = px.pie(df_Accs_sort, values='value', names='Country Name', title='TOP 3 Countries by 2015 Access to electricity, urban (% of urban population)',template=list(plotly.io.templates.keys())[5])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_coal =  df.query("indicator == 'EG.ELC.COAL.ZS'")
df_coal = df_coal[df_coal["Country Code"].isin(["CHN","IND","USA"])]

# %%
df_coal =  df.query("indicator == 'EG.ELC.COAL.ZS'")
df_coal = df_coal[df_coal["Country Code"].isin(["CHN","IND","USA"])]

fig = px.line(
    df_coal, 
    x="Year", 
    labels={"value":"Electricity production from coal sources"},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5],
    title="TOP 3 Countries by 2015 Electricity production from coal sources (% of total)"

)


fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_hydro =  df.query("indicator == 'EG.ELC.HYRO.ZS'")
df_hydro = df_hydro[df_hydro["Country Code"].isin(["CHN","IND","USA"])]

# %%
df_hydro =  df.query("indicator == 'EG.ELC.HYRO.ZS'")
df_hydro = df_hydro[df_hydro["Country Code"].isin(["CHN","IND","USA"])]

fig = px.line(
    df_hydro, 
    x="Year", 
    labels={"value":"Electricity production from hydro sources"},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5],
    title="TOP 3 Countries by 2015 Electricity production from hydro sources (% of total)"

)


fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_All = df.query("Year == 2012").query("indicator == 'EG.ELC.FOSL.ZS'")

df_All_sort = df_All.sort_values(by= "value", ascending= False)
df_All_sort
# Out:
#     Unnamed: 0  Year      value       indicator Country Code   Country Name  \
# 8            8  2012  81.287370  EG.ELC.FOSL.ZS          IND          India
# 2            2  2012  77.859893  EG.ELC.FOSL.ZS          CHN          China
# 14          14  2012  68.862840  EG.ELC.FOSL.ZS          USA  United States
#
#                  Region         Income Group    Lending Type
# 8            South Asia  Lower middle income            IBRD
# 2   East Asia & Pacific  Upper middle income            IBRD
# 14        North America          High income  Not classified

# %%
fig = px.pie(df_All_sort, values='value', names='Country Name', title='Electricity production from coal,hydro and oil resources',template=list(plotly.io.templates.keys())[5])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_cons = df.query("indicator in(['EG.ELC.ACCS.RU.ZS','EG.ELC.FOSL.ZS','EG.USE.ELEC.KH.PC','SP.POP.TOTL'])")
df_cons
# Out:
#      Unnamed: 0  Year         value       indicator Country Code  \
# 0             0  2010  7.940103e+01  EG.ELC.FOSL.ZS          CHN
# 1             1  2011  8.117400e+01  EG.ELC.FOSL.ZS          CHN
# 2             2  2012  7.785989e+01  EG.ELC.FOSL.ZS          CHN
# 3             3  2013  7.742447e+01  EG.ELC.FOSL.ZS          CHN
# 4             4  2014  7.482289e+01  EG.ELC.FOSL.ZS          CHN
# ..          ...   ...           ...             ...          ...
# 190         190  2016  3.230718e+08     SP.POP.TOTL          USA
# 191         191  2017  3.251221e+08     SP.POP.TOTL          USA
# 192         192  2018  3.268382e+08     SP.POP.TOTL          USA
# 193         193  2019  3.283300e+08     SP.POP.TOTL          USA
# 194         194  2020  3.294841e+08     SP.POP.TOTL          USA
#
#       Country Name               Region         Income Group    Lending Type
# 0            China  East Asia & Pacific  Upper middle income            IBRD
# ...

# %%
fig = px.pie(df_cons, values='value', names='Country Name', title='Electricity consumption by three countries',template=list(plotly.io.templates.keys())[5])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_kg = df.query("indicator in(['	EG.ELC.ACCS.UR.ZS','	EG.ELC.LOSS.ZS','	EG.ELC.HYRO.ZS','SP.POP.TOTL','	EG.USE.PCAP.KG.OE','EG.ELC.COAL.ZS','	EG.ELC.ACCS.RU.ZS'])")

# %%
fig = px.line(
    df_kg, 
    x="Year", 
    labels={"value":"Electricity consumption by three countries"},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5],
    title="TOP 3 Countries by 2015 Electricity consumption in kg"

)


fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_loss = df.query("indicator in(['EG.ELC.LOSS.ZS', 'SP.POP.TOTL'])")

# %%
fig = px.bar(
    df_loss, 
    x="Country Name", 
    labels={"value":"2010 Electric power transmission and distribution loss"},
    y="value",
    color="Country Name",
    height=700,
    template=list(plotly.io.templates.keys())[5],
    title="Top 3 countries by 2015 Access to electricity(% of population)"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
